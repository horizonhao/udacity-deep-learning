# %% [markdown]
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
# is it really necessary to make this code so ugly and unreadable?
# so weird code!!!

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.676923
# Nearest to between: patrimony, ontario, constituencies, schedules, superimposed, balearic, matisse, stool,
# Nearest to been: aarhus, commons, bgcolor, sachs, dan, deficiency, screenwriters, pieces,
# Nearest to will: disadvantage, jagged, pelias, acrobatic, behest, napoleonic, torgau, barber,
# Nearest to would: bangladeshis, leet, plowing, religion, alba, bromwich, remastered, automated,
# Nearest to is: soo, monotheism, otto, rockin, equ, malaysians, fins, satsuki,
# Nearest to his: watertown, kong, zug, kidd, tacitly, provability, tara, bafta,
# Nearest to if: lever, glyph, ngo, genuine, mousse, front, loving, satellite,
# Nearest to as: corcovado, lothian, hayling, hadad, goddesses, kalmar, pluralism, childhood,
# Nearest to one: fuzes, partners, solemnity, ipc, annoying, olympian, microkernel, naiste,
# Nearest to united: landline, conjunction, rockers, disseminated, carbines, isomers, carcinoma, summons,
# Nearest to who: sempronius, harm, penetrate, boole, gliding, blurred, maul, composting,
# Nearest to d: mojito, attend, assaulted, waterman, groton, projector, salad, udp,
# Nearest to eight: woodward, iigs, baldr, kuhn, lecompton, sds, peanuts, girlfriend,
# Nearest to seven: fennel, projection, toed, gerhard, barrett, yves, adversarial, diff,
# Nearest to a: petitioning, transporters, wholeheartedly, angelo, algebraic, yeho, stabilize, terribly,
# Nearest to they: paparazzi, magnates, micronation, whales, feed, safely, blossom, ecclesiastica,
# Average loss at step 2000: 4.353438
# Average loss at step 4000: 3.863983
# Average loss at step 6000: 3.786878
# Average loss at step 8000: 3.685413
# Average loss at step 10000: 3.613110
# Nearest to between: with, in, smelter, naturally, ono, ontario, transaction, among,
# Nearest to been: by, aarhus, matriculation, be, was, also, forth, apap,
# Nearest to will: favorites, expandable, uproar, to, cdc, classless, could, must,
# Nearest to would: can, to, could, should, may, wiley, where, must,
# Nearest to is: was, are, has, inconspicuous, be, exilic, gustavus, prays,
# Nearest to his: s, their, her, the, its, occurred, detainee, kidd,
# Nearest to if: lever, glyph, lok, loving, can, soi, confessed, projectiles,
# Nearest to as: lothian, adventurer, phage, privatize, kalmar, by, make, decimals,
# Nearest to one: two, three, seven, five, four, six, eight, nine,
# Nearest to united: landline, summons, disseminated, carbines, sukhum, rockers, isomers, carcinoma,
# Nearest to who: sempronius, he, guarded, and, consisted, which, they, blurred,
# Nearest to d: cleaning, inexplicably, asymmetrical, smallpox, projector, moluccas, mojito, japh,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to a: the, this, glowing, his, deeps, graph, stevenson, graduated,
# Nearest to they: he, not, we, it, there, frisia, enlists, who,
# Average loss at step 12000: 3.605138
# Average loss at step 14000: 3.566397
# Average loss at step 16000: 3.409025
# Average loss at step 18000: 3.459111
# Average loss at step 20000: 3.538644
# Nearest to between: with, among, scalia, smelter, naturally, in, and, abuser,
# Nearest to been: be, become, were, by, was, apap, forth, fink,
# Nearest to will: would, may, could, favorites, can, must, to, traced,
# Nearest to would: could, can, may, will, should, must, might, to,
# Nearest to is: was, has, are, be, were, prays, ingolstadt, hazel,
# Nearest to his: their, her, its, the, jirga, occurred, scans, kidd,
# Nearest to if: lok, when, does, can, loving, hamar, wheeling, mithraic,
# Nearest to as: record, lasted, hemlock, discontinuous, venezuelan, for, auspicious, make,
# Nearest to one: two, four, three, seven, eight, five, six, zero,
# Nearest to united: sukhum, landline, around, summons, conjunction, disseminated, rockers, mestizos,
# Nearest to who: he, which, guarded, sempronius, they, and, often, also,
# Nearest to d: b, asymmetrical, japh, inexplicably, moluccas, cleaning, leo, projector,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Nearest to a: deeps, this, stevenson, bumped, no, any, hei, another,
# Nearest to they: we, he, there, it, you, not, who, she,
# Average loss at step 22000: 3.501525
# Average loss at step 24000: 3.490417
# Average loss at step 26000: 3.478208
# Average loss at step 28000: 3.476016
# Average loss at step 30000: 3.503951
# Nearest to between: with, among, in, naturally, abuser, scalia, lipstick, ferraris,
# Nearest to been: become, was, be, were, forth, rode, fink, banzer,
# Nearest to will: would, can, could, may, must, should, shall, favorites,
# Nearest to would: can, could, may, will, must, should, might, cannot,
# Nearest to is: was, has, are, became, if, does, be, were,
# Nearest to his: their, her, its, the, jirga, s, retaken, occurred,
# Nearest to if: when, is, where, lok, wheeling, does, but, can,
# Nearest to as: reveal, ifor, shorthand, phage, by, ecologist, strong, pale,
# Nearest to one: two, seven, four, six, eight, five, nine, three,
# Nearest to united: sukhum, conjunction, landline, antigonus, carbines, around, disseminated, summons,
# Nearest to who: he, guarded, they, sempronius, she, which, allen, thorny,
# Nearest to d: b, inexplicably, cleaning, japh, asymmetrical, moluccas, english, macao,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to seven: eight, four, nine, five, six, three, zero, two,
# Nearest to a: any, the, graduated, no, spray, dials, assessments, their,
# Nearest to they: there, he, we, it, you, not, who, rachael,
# Average loss at step 32000: 3.504100
# Average loss at step 34000: 3.494796
# Average loss at step 36000: 3.451510
# Average loss at step 38000: 3.298179
# Average loss at step 40000: 3.429962
# Nearest to between: with, among, abuser, within, patrimony, naturally, lipstick, scalia,
# Nearest to been: become, be, was, were, previously, overstated, brownlow, fink,
# Nearest to will: would, can, could, may, must, should, might, to,
# Nearest to would: could, will, can, may, should, might, must, did,
# Nearest to is: was, are, be, if, crumbling, has, kroon, bbses,
# Nearest to his: their, her, its, my, jirga, s, the, bodhisattvas,
# Nearest to if: when, where, is, can, synonyms, batch, for, cooled,
# Nearest to as: reveal, goss, ecologist, tune, whitbread, pale, newfound, castiglione,
# Nearest to one: four, two, seven, six, nine, eight, three, five,
# Nearest to united: sukhum, conjunction, mestizos, reinforcements, lex, senate, carbines, antigonus,
# Nearest to who: he, often, which, guarded, sempronius, she, allen, also,
# Nearest to d: b, UNK, japh, asymmetrical, inexplicably, cleaning, matthew, smallpox,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to seven: five, eight, nine, six, four, three, zero, two,
# Nearest to a: the, another, any, assessments, no, deeps, or, tellers,
# Nearest to they: we, there, he, you, it, she, rachael, not,
# Average loss at step 42000: 3.435499
# Average loss at step 44000: 3.456767
# Average loss at step 46000: 3.446717
# Average loss at step 48000: 3.351891
# Average loss at step 50000: 3.382149
# Nearest to between: with, among, abuser, in, within, scalia, naturally, kemal,
# Nearest to been: become, be, was, had, were, previously, overstated, sacd,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to would: will, could, can, may, might, should, must, did,
# Nearest to is: was, has, are, becomes, became, contains, be, does,
# Nearest to his: their, her, its, the, my, your, our, him,
# Nearest to if: when, where, although, while, though, before, reduces, amaterasu,
# Nearest to as: reveal, ifor, moussa, mongoloid, dolmen, phage, sega, seem,
# Nearest to one: two, eight, six, four, five, seven, nine, three,
# Nearest to united: lex, conjunction, sukhum, mestizos, reinforcements, antigonus, rockers, minimum,
# Nearest to who: he, she, which, sempronius, guarded, deacidification, allen, also,
# Nearest to d: b, japh, asymmetrical, bolshevist, inexplicably, matthew, smallpox, assaulted,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to seven: six, eight, nine, four, three, five, zero, two,
# Nearest to a: the, another, assessments, nel, retinal, any, no, intimately,
# Nearest to they: we, he, there, you, she, it, these, infra,
# Average loss at step 52000: 3.440773
# Average loss at step 54000: 3.428665
# Average loss at step 56000: 3.439751
# Average loss at step 58000: 3.398139
# Average loss at step 60000: 3.392763
# Nearest to between: with, among, within, in, abuser, scalia, naturally, patrimony,
# Nearest to been: become, be, was, previously, were, had, overstated, grown,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to would: could, will, may, can, might, must, should, did,
# Nearest to is: was, has, are, although, does, if, contains, became,
# Nearest to his: her, their, its, my, the, our, disparaging, jirga,
# Nearest to if: when, where, although, before, though, while, since, is,
# Nearest to as: reveal, whitbread, goss, metabolic, dikes, became, seem, glutinous,
# Nearest to one: two, four, six, eight, seven, nine, three, five,
# Nearest to united: lex, sukhum, mestizos, reinforcements, minimum, conjunction, judaizers, census,
# Nearest to who: she, he, sempronius, which, never, often, allen, guarded,
# Nearest to d: b, asymmetrical, japh, h, bolshevist, assaulted, arabella, macao,
# Nearest to eight: nine, six, four, seven, five, three, zero, one,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to a: the, another, any, knit, retinal, wander, assessments, too,
# Nearest to they: we, there, he, you, she, it, not, these,
# Average loss at step 62000: 3.239475
# Average loss at step 64000: 3.257087
# Average loss at step 66000: 3.400243
# Average loss at step 68000: 3.394606
# Average loss at step 70000: 3.352562
# Nearest to between: among, with, within, in, abuser, from, patrimony, appealing,
# Nearest to been: become, be, was, previously, were, grown, already, had,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to is: was, has, are, be, contains, becomes, kamenev, although,
# Nearest to his: her, their, its, my, our, your, the, disparaging,
# Nearest to if: when, where, before, though, while, however, although, could,
# Nearest to as: reveal, seem, whitbread, when, because, phage, ecologist, is,
# Nearest to one: two, six, eight, seven, four, five, nine, three,
# Nearest to united: lex, sukhum, andes, reinforcements, mestizos, census, conjunction, minimum,
# Nearest to who: she, he, guarded, sempronius, born, allen, deacidification, they,
# Nearest to d: b, asymmetrical, japh, h, bestseller, mano, leo, cladogram,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to seven: six, eight, nine, four, five, three, two, zero,
# Nearest to a: another, the, any, andrade, assessments, alliaceae, courted, modeled,
# Nearest to they: we, he, there, you, she, it, infra, then,
# Average loss at step 72000: 3.372403
# Average loss at step 74000: 3.344078
# Average loss at step 76000: 3.311126
# Average loss at step 78000: 3.348668
# Average loss at step 80000: 3.375961
# Nearest to between: within, among, with, kemal, naturally, across, abuser, in,
# Nearest to been: become, be, previously, were, already, was, grown, had,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to is: was, has, are, remains, became, be, although, does,
# Nearest to his: her, their, its, my, our, your, the, lugh,
# Nearest to if: when, though, before, where, although, since, then, while,
# Nearest to as: newfound, reveal, scent, whitbread, lubricant, sega, seasoned, slight,
# Nearest to one: seven, six, two, four, eight, three, five, nine,
# Nearest to united: lex, census, conjunction, andes, ninth, mestizos, sukhum, reinforcements,
# Nearest to who: he, she, guarded, which, born, they, often, never,
# Nearest to d: b, asymmetrical, p, l, h, pio, bolshevist, insult,
# Nearest to eight: six, nine, five, seven, four, three, zero, two,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to a: another, the, nel, transporters, every, modeled, deeps, retinal,
# Nearest to they: we, he, there, you, she, it, infra, controllers,
# Average loss at step 82000: 3.406285
# Average loss at step 84000: 3.410098
# Average loss at step 86000: 3.391431
# Average loss at step 88000: 3.347841
# Average loss at step 90000: 3.361576
# Nearest to between: within, among, with, through, across, ferraris, abuser, scalia,
# Nearest to been: become, be, was, previously, already, grown, overstated, had,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to is: was, has, are, becomes, hazel, be, although, ambient,
# Nearest to his: her, their, its, my, our, your, the, pragmatism,
# Nearest to if: when, where, though, although, since, before, unless, is,
# Nearest to as: reveal, lessens, alston, seasoned, dolmen, maverick, luminosity, officeholders,
# Nearest to one: seven, four, eight, two, six, three, five, nine,
# Nearest to united: lex, andes, ninth, conjunction, census, mestizos, sukhum, supreme,
# Nearest to who: she, often, he, born, which, guarded, finns, still,
# Nearest to d: b, h, smilga, mano, asymmetrical, japh, horrified, yung,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to a: another, retinal, the, intimately, knit, nel, any, wander,
# Nearest to they: we, he, there, you, she, it, infra, these,
# Average loss at step 92000: 3.397058
# Average loss at step 94000: 3.246797
# Average loss at step 96000: 3.358636
# Average loss at step 98000: 3.244644
# Average loss at step 100000: 3.354691
# Nearest to between: with, among, within, scalia, across, through, gangetic, around,
# Nearest to been: become, be, already, grown, was, previously, overstated, recently,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to would: will, could, might, can, may, should, must, cannot,
# Nearest to is: was, has, became, tackles, be, becomes, are, remains,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to if: when, though, where, before, although, since, exilic, unless,
# Nearest to as: reveal, sega, goss, bastille, when, stretching, like, luminosity,
# Nearest to one: two, four, seven, eight, five, three, six, nine,
# Nearest to united: lex, andes, ninth, census, sukhum, senate, mestizos, supreme,
# Nearest to who: she, he, guarded, that, still, which, often, never,
# Nearest to d: b, l, smilga, mor, japh, p, asymmetrical, h,
# Nearest to eight: nine, seven, five, six, four, zero, three, two,
# Nearest to seven: four, eight, six, five, nine, three, zero, two,
# Nearest to a: another, the, any, modeled, andrade, knit, cleves, sampler,
# Nearest to they: we, he, there, you, she, it, infra, i,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
